# %% [markdown]
# <a href="https://colab.research.google.com/github/vkjadon/python/blob/main/05oop_robot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introducing Class and Object

# %% [markdown]
# A class provides a blueprint or template for creating objects. It defines a set of attributes and methods for the objects that we create from the buleprint of a class.
#
# Whereas, an object is an instance of a class. It represents a specific implementation of the class, with its <b>own</b> set of attributes and behaviors.
#
# The class is just like designing a form.  The forms contain some fields that are same for the any person/object but the entries are different. The form represents a class and the fields represents the attributes. We can take example of account opening form where every person fill that form to open account (object/instance).
#
# We can represent a class by '<b>class</b>' keyword as below.

# %%
class Robot:
    pass

# %% [markdown]
# This creates a 'Robot' class but we have not added any fields (attributes) in that template of <b>Robot</b>. It is a common convention that the class name starts with a uppercase.
#
# We can create object of this class by instantiating the class as below:

# %%
my_first_robot=Robot()
my_second_robot=Robot()

# %%
print(my_first_robot)
print(my_second_robot)
# Out:
# <__main__.Robot object at 0x7b3590bde260>
# <__main__.Robot object at 0x7b3590bddb70>

# %% [markdown]
# This tells us that 'my_first_robot' and 'my_second_robot' are the instances of the Robot class, which is defined in the __main__ module. The last values are the memory address where the objects are stored during execution. These are hexadecimal value and are unique to a particular instance.

# %% [markdown]
# As we create any object of a class by instantiating a class, that is why we also call the object as the instance of that class. The meaning remains the same. So, you should not be confused in case we write object or instance of a class.

# %% [markdown]
# # Adding Attributes to a Class : Instance Variable

# %% [markdown]
# Attributes are properties that belong to a class or instances of a class. They can be divided into two main categories of <b>class variable </b> and <b>instance variable</b>.

# %%
class Robot:
    name = None
    model = None

my_first_robot=Robot()

print(my_first_robot.name)
print(my_first_robot.model)
# Out:
# None
# None

# %% [markdown]
# In the example of 'Robot' class, we have added two attributes of 'name' and 'model'. These are the instance variables and are accessible only through the specific instance. When we create any object using this class, these attributes are automatically assigned to the object.
# In this example, <b>None</b> is assigned to the $name$ and $model$. These are accessed using ***attribute access operator***; the 'dot' (.) on the object.

# %% [markdown]
# # Assigning Value to Instance Variable

# %% [markdown]
# Here we have added two attributes but the 'None' is assigned. We can assign the 'name' and 'model' using ***attribute access operator***; 'dot' (.) as below:

# %%
my_first_robot.name="R2D2"
my_first_robot.model="Droid"

# %%
my_second_robot.name="C3PO"
my_second_robot.model="Droid2"

# %%
print(my_first_robot.name)
print(my_second_robot.model)
# Out:
# R2D2
# Droid2

# %% [markdown]
# We can assign the attribute using the this method but it is not very convenient when the attributes increases So, we use a function called constructor method to add attributes to a class. In python OOPS concepts, the functions are called as methods. So, during the discussion, we will be using method and function interchageably.

# %% [markdown]
# # Add Parameters to Class Constructor

# %% [markdown]
# In python, the constructor method is defined in ' _ _ init _ _ '. The first parameter in the constructor is 'self' which represent the instance of the class.
#
# Add 'name' and 'model' as attributes of the Robot Class. In the context of the variable, the 'name' and 'model' are the attribute classified in the category of instance variable.

# %%
class Robot():
  # def __init__(name, model):
  def __init__(vkj, name, model):
  # def __init__(self, name, model):
    vkj.name = name
    vkj.model = model

my_first_robot=Robot("R2D2", "Droid")
my_second_robot=Robot("C3PO", "Droid")

print(my_first_robot.model)
# Out:
# Droid

# %% [markdown]
# When we instantiate a class and create 'my_first_robot', the name of the object 'my_first_robot' is passed to the constructor <b>by default</b> and 'self' takes the name of the object. You can use any other variable to replace self, but it is a common practice in python to use 'self' to represent the instance or passing 'object name'
#
# Also, we can access the Robot Class attributes from the outside of the class.
#
# It is important to note the number of arguements we pass in the function call should be the same as the number of parameters we use to define a function.

# %% [markdown]
# # Add a method to the class

# %% [markdown]
# A method in a class is a function that is defined within a class and operates on instances of that class. Methods are used to define behaviors and actions of the objects. We can also use methods to access and modify the attributes.
#
# Methods can be categorized into <b>instance methods</b>, <b>class methods</b>, and <b>static methods</b>.

# %%
class Robot():
  def __init__(self, name, model):
    self.name = name
    self.model = model

  def robot_info(self):
    print(self, "Name : ", self.name, "| Model : ", self.model)

# %% [markdown]
# ## Calling an Instance Method

# %% [markdown]
# We can call the method using class or object/instance. To call a method, the syntax is to use object name followed by ' . (dot) ', followed by method.
#
# So method call is <p><b> my_second_robot.robot_info() </b></p>

# %%
my_first_robot=Robot("R2D2", "Droid")
my_second_robot=Robot("C3PO", "Droid")

# print(my_robot)
print(f"The name of my_robot is {my_first_robot.name}")

# print(my_second_robot)
my_second_robot.robot_info()
# Out:
# The name of my_robot is R2D2
# <__main__.Robot object at 0x7b3590bdd720> Name :  C3PO | Model :  Droid

# %% [markdown]
# ## Calling an Instance Method on Class
#
# Let us try to call a method on class.

# %%
# Robot.robot_info()
Robot.robot_info(self)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-134-f978b76b29a6> in <cell line: 2>()
#       1 # Robot.robot_info()
# ----> 2 Robot.robot_info(self)
#
# NameError: name 'self' is not defined

# %% [markdown]
# Throws error in both the cases

# %% [markdown]
# We can call any instance method on class. In this case we use class name then dot (.) followed by method name and pass the instance of the class (object) as an arguement to the methos as below.
#
# <p>
#   <b>Robot.robot_info(my_robot)</b>
# </p>

# %%
Robot.robot_info(my_first_robot)
# Out:
# <__main__.Robot object at 0x7b3590bdf2e0> Name :  R2D2 | Model :  Droid

# %% [markdown]
# One very common mistake about creating a method is that we miss to add 'self' as the first parameter of the method. Actually, when we call any methon on any instance or object of any class, the instance is automatically passed as an arguement with other arguements. So, it is must to use self in the method defination else an exception will occur.

# %%
class Robot():
  def __init__(self, name, model):
    self.name = name
    self.model = model

  def robot_info(self):
  # def robot_info():
    # print(self, "Name : ", self.name, "| Model : ", self.model)
    print("Name : ", self.name, "| Model : ", self.model)
    # print("Name : ", name, "| Model : ", model)

my_first_robot=Robot("R2D2", "Droid")
Robot.robot_info(my_first_robot)
# Out:
# Name :  R2D2 | Model :  Droid

# %% [markdown]
# ##'_ _ repr _ _' method

# %% [markdown]
# Python default display for an object is the class and memory location. You can customize this output using user-defined '_ _ repr _ _()' method.

# %%
class Robot():
  def __init__(self, name, model):
    self.name = name
    self.model = model

  def robot_info(self):
    print(self, "Name : ", self.name, "| Model : ", self.model)

  def __repr__(self):
    return f"Robot(name={self.name}, model={self.model})"

my_first_robot=Robot("R2D2", "Droid")
print(my_first_robot)
print(my_first_robot.robot_info())
# Out:
# Robot(name=R2D2, model=Droid)
# Robot(name=R2D2, model=Droid) Name :  R2D2 | Model :  Droid
# None

# %% [markdown]
# # Add Robot Components : Composition
#
# Composition is a technique to add one or more objects from one or more classes to another class.
#
# Let us add battery to begin with by creating a Battery Class and add one attribute 'capacity' to this class.

# %%
class Battery:
  def __init__(self, capacity):
    self.capacity = capacity

# %% [markdown]
# Now, create two battery objects of 'Battery' class.

# %%
# Create instances of Battery
battery1 = Battery(5000)
battery2 = Battery(8000)
print(f"The capacity of battery1 is {battery1.capacity}")
print(f"The capacity of battery2 is {battery2.capacity}")
# Out:
# The capacity of battery1 is 5000
# The capacity of battery2 is 8000

# %% [markdown]
# We can add these objects of 'Battery' class to form a 'Robot' class. We need to change the Robot Class by adding battery Object as parameter and add that as attribute.

# %%
class Robot():
  def __init__(self, name, model, battery):
    self.name = name
    self.model = model
    self.battery = battery

  def robot_info(self):
    print(self, "Name : ", self.name, "| Model : ", self.model, "| Battery : ", self.battery.capacity)

  def __repr__(self):
    return f"Robot(name={self.name}, model={self.model})"

# %%
# Create instances of Robot
my_first_robot=Robot("R2D2", "Droid", battery1)
my_second_robot=Robot("C3PO", "Droid", battery2)

# %% [markdown]
# In the first case, 'my_first_robot' is the object of the Robot class and when we instantiate this class, another object (battery1) of another class (Battery) is passed. You can access the attribute of the Battery class through the object of Robot class using the 'battery' attribute.

# %%
print(my_first_robot.battery.capacity)
print(my_second_robot.battery.capacity)
# Out:
# 5000
# 8000

# %% [markdown]
# Print the objects Info

# %%
my_first_robot.robot_info()
my_second_robot.robot_info()
# Out:
# Robot(name=R2D2, model=Droid) Name :  R2D2 | Model :  Droid | Battery :  5000
# Robot(name=C3PO, model=Droid) Name :  C3PO | Model :  Droid | Battery :  8000

# %% [markdown]
# Let us add two methods in the Battery class to update the parameter 'charge_level'; charge() method to represent the fully charged battery and discharge() method to represent the discharge amount required as below:

# %%
# Battery class
class Battery:
  def __init__(self, capacity, charge_level):
    self.capacity = capacity  # Capacity in mAh
    self.charge_level = charge_level  # Current charge percentage

  def charge(self):
    self.charge_level = 100
    print("Battery fully charged.")

  def discharge(self, amount):
    if self.charge_level - amount >= 0:
      self.charge_level -= amount
      print(f"Battery discharged by {amount}%. Current charge: {self.charge_level}%.")
    else:
      print("Not enough charge to discharge by that amount!")

# %%
# Robot class
class Robot:
    def __init__(self, name, model, battery):
        self.name = name
        self.model = model
        self.battery = battery  # Composition: Robot has a Battery

    def robot_info(self):
        print(f"Name: {self.name} | Model: {self.model} | Battery: {self.battery.capacity}mAh, {self.battery.charge_level}% charge")

# %%
# Example usage
first_robot_battery = Battery(capacity=5000, charge_level=75)
my_first_robot = Robot(name="RoboMax", model="X200", battery=first_robot_battery)

second_robot_battery = Battery(capacity=2000, charge_level=95)
my_second_robot = Robot(name="RoboMax2", model="Y200", battery=second_robot_battery)

# Display robot info
my_first_robot.robot_info()
my_second_robot.robot_info()
# Out:
# Name: RoboMax | Model: X200 | Battery: 5000mAh, 75% charge
# Name: RoboMax2 | Model: Y200 | Battery: 2000mAh, 95% charge

# %%
# Interact with the battery through the composition
my_first_robot.battery.discharge(20)
my_first_robot.robot_info()
# Out:
# Battery discharged by 20%. Current charge: 55%.
# Name: RoboMax | Model: X200 | Battery: 5000mAh, 55% charge

# %%
my_first_robot.battery.charge()
my_first_robot.robot_info()
# Out:
# Battery fully charged.
# Name: RoboMax | Model: X200 | Battery: 5000mAh, 100% charge

# %% [markdown]
# Let us now add one more component Motor with power as one attribute.

# %%
class Motor:
  def __init__(self, power):
    self.power = power

# %%
# Create instances of Motor
motor200 = Motor(200)

# %% [markdown]
# Attach motor to Robots by modifying the Robot Class

# %%
class Robot():
  def __init__(self, name, model, battery, motor):
    self.name = name
    self.model = model
    self.battery = battery
    self.motor = motor

  def robot_info(self):
    print(self, "Name : ", self.name, "| Model : ", self.model, "| Battery : ", self.battery.capacity, "kWh| Motor : ", self.motor.power, "Watt")

# %% [markdown]
# Update the instances of the class to add object of Motor class as an arguement

# %%
# Create instances of Robot
my_first_robot=Robot("R2D2", "Droid", first_robot_battery, motor200)
my_second_robot=Robot("C3PO", "Droid", second_robot_battery, motor200)

my_first_robot.robot_info()
my_second_robot.robot_info()
# Out:
# <__main__.Robot object at 0x7b3590bdc310> Name :  R2D2 | Model :  Droid | Battery :  5000 kWh| Motor :  200 Watt
# <__main__.Robot object at 0x7b3590bdee60> Name :  C3PO | Model :  Droid | Battery :  2000 kWh| Motor :  200 Watt

# %% [markdown]
# Our robot must have some sesnsors. The important sensors are range finder, imu, camera etc. Create classes for each of these.

# %%
# Define the RangeFinder class
class RangeFinder:
  def __init__(self, model, min_range, max_range):
    self.model = model
    self.min_range = min_range
    self.max_range = max_range

# Define the IMU class
class IMU:
  def __init__(self, model):
    self.model = model

# Define the Camera class
class Camera:
  def __init__(self, model, resolution):
    self.model = model
    self.resolution = resolution

# %% [markdown]
# Create sensor objects 'range_finder', 'imu' and 'camera' by instantiating their respective classes.

# %%
Ultrasonic_HC_SR04 = RangeFinder("Ultrasonic", 1, 100)
imu_MPU6050 = IMU("MPU6050")
camera_Pana12 = Camera("Panasonic", "12MP")

# %% [markdown]
# Update the Robot Class to add sensors attributes and update the 'robot_info' method to display sensors on the

# %%
class Robot():
  def __init__(self, name, model, battery, motor, range_finder, imu, camera):
    self.name = name
    self.model = model
    self.battery = battery
    self.motor = motor
    self.range_finder = range_finder
    self.imu = imu
    self.camera = camera

  def robot_info(self):
    print("Name : ", self.name, "| Model : ", self.model, "| Battery : ", self.battery.capacity, "kWh| Motor : ", self.motor.power, "Watt")
    print("\nThe Robot is equipped with the following Sensors : ")
    print(f"\nRange Finder  {self.range_finder.model} IMU  {self.imu.model} Camera  {self.camera.model}")

# %% [markdown]
# Update the robot objects.

# %%
# Create instances of Robot
my_first_robot=Robot("R2D2", "Droid", first_robot_battery, motor200, Ultrasonic_HC_SR04, imu_MPU6050, camera_Pana12)
my_first_robot.robot_info()
# print("\t",camera_Pana12.resolution)
# Out:
# Name :  R2D2 | Model :  Droid | Battery :  5000 kWh| Motor :  200 Watt
#
# The Robot is equipped with the following Sensors :
#
# Range Finder  Ultrasonic IMU  MPU6050 Camera  Panasonic

# %% [markdown]
# As the components keep on increasing, the attributes list goes on longer. One method to clean our code is to pass the sensors in one dictionary. Let us create one dictionary with the name 'sensors' and add all the sensors in it.

# %%
Lidar = RangeFinder("LiDAR", 1, 100)
camera_Sam20 = Camera("Panasonic", "12MP")

# %%
sensors_set1={'range_finder':Ultrasonic_HC_SR04, 'imu':imu_MPU6050, 'camera':camera_Pana12}
sensors_set2={'range_finder':Lidar, 'imu':imu_MPU6050, 'camera':camera_Sam20}

# %% [markdown]
# Now, we can pass this dictionary when we create our Robot

# %%
class Robot():
  def __init__(self, name, model, battery, motor, sensors):
    self.name = name
    self.model = model
    self.battery = battery
    self.motor = motor
    self.sensors = sensors
    print(self.sensors)

  def robot_info(self):
    print("Name : ", self.name, "| Model : ", self.model, "| Battery : ", self.battery.capacity, "kWh| Motor : ", self.motor.power, "Watt")
    print("\nIMU  {self.sensors['imu'].model}")

# %%
my_first_robot=Robot("R2D2", "Droid", first_robot_battery, motor200, sensors_set1)
# my_first_robot.robot_info()
# my_first_robot.name
# Out:
# {'range_finder': <__main__.RangeFinder object at 0x7b3590bdcd90>, 'imu': <__main__.IMU object at 0x7b3590bdc1f0>, 'camera': <__main__.Camera object at 0x7b3590bdc490>}

# %% [markdown]
# Let us add another behaviour in the Robot class.

# %%
class Robot():
  def __init__(self, name, model, battery, motor, sensors):
    self.name = name
    self.model = model
    self.battery = battery
    self.motor = motor
    self.sensors = sensors
    print(self.sensors)

  def robot_info(self):
    print("Name : ", self.name, "| Model : ", self.model, "| Battery : ", self.battery.capacity, "kWh| Motor : ", self.motor.power, "Watt")
    print("\nIMU  {self.sensors['imu'].model}")

  def move(self, direction, distance):
      print(f"{self.name} (model {self.model}) is moving to the {direction} for {distance} meters")

# %%
my_first_robot=Robot("R2D2", "Droid", first_robot_battery, motor200, sensors_set1)
my_first_robot.move("Left", 5)
# Out:
# {'range_finder': <__main__.RangeFinder object at 0x7b3590bdcd90>, 'imu': <__main__.IMU object at 0x7b3590bdc1f0>, 'camera': <__main__.Camera object at 0x7b3590bdc490>}
# R2D2 (model Droid) is moving to the Left for 5 meters

# %% [markdown]
# # Understanding '_ _ dict _ _'

# %% [markdown]
# '_ _ dict _ _' is an attribute of an object that stores all its attributes in a dictionary. This is a special attribute of an object and is automatically assigned. We can access this by using attribute access operator; 'dot' (.).

# %%
print(my_first_robot.__dict__)
# Out:
# {'name': 'R2D2', 'model': 'Droid', 'battery': <__main__.Battery object at 0x7b3590bdc610>, 'motor': <__main__.Motor object at 0x7b3590bdf790>, 'sensors': {'range_finder': <__main__.RangeFinder object at 0x7b3590bdcd90>, 'imu': <__main__.IMU object at 0x7b3590bdc1f0>, 'camera': <__main__.Camera object at 0x7b3590bdc490>}}

# %% [markdown]
# The output of this is a dictionary where the keys are attribute names (as strings) and the values are the corresponding attribute values.
#
# We can also modify and/or add attributes dynamically using '_ _ dict _ _'.

# %%
# Modify an attribute using __dict__
my_first_robot.__dict__['name'] = "R789"

# Add a new attribute using __dict__
my_first_robot.__dict__['material'] = "Steel"

print(my_first_robot.__dict__)
# Out:
# {'name': 'R789', 'model': 'Droid', 'battery': <__main__.Battery object at 0x7b3590bdc610>, 'motor': <__main__.Motor object at 0x7b3590bdf790>, 'sensors': {'range_finder': <__main__.RangeFinder object at 0x7b3590bdcd90>, 'imu': <__main__.IMU object at 0x7b3590bdc1f0>, 'camera': <__main__.Camera object at 0x7b3590bdc490>}, 'material': 'Steel'}

# %%
print(first_robot_battery.__dict__)
first_robot_battery.__dict__['capacity'] = "4550"
print(first_robot_battery.__dict__)
print(my_first_robot.__dict__)
print(my_first_robot.battery.capacity)
# Out:
# {'capacity': 5000, 'charge_level': 100}
# {'capacity': '4550', 'charge_level': 100}
# {'name': 'R789', 'model': 'Droid', 'battery': <__main__.Battery object at 0x7b3590bdc610>, 'motor': <__main__.Motor object at 0x7b3590bdf790>, 'sensors': {'range_finder': <__main__.RangeFinder object at 0x7b3590bdcd90>, 'imu': <__main__.IMU object at 0x7b3590bdc1f0>, 'camera': <__main__.Camera object at 0x7b3590bdc490>}, 'material': 'Steel'}
# 4550

# %%
print(my_first_robot.battery.capacity)
# Out:
# 4550

# %% [markdown]
# This represents that when we changed the capacity of the 'batter1' and checked the namespace of 'my_first_robot', we found the data is changed to the new value. As we are refererring to the 'battery' object. When we call 'capacity attribute' through the instance of the Robot class, it reaches to the capacity through the 'Battery' class.

# %% [markdown]
# # Class Variables

# %% [markdown]
# A class variable is a variable that is shared among all instances of a class. It is defined within a class but outside any instance methods or constructors (' _ _ init _ _' method). Class variables are used to store data that is common to all objects of the class.

# %%
class Robot():

  robot_base_cost = 100000

  def __init__(self, name, model, battery, motor, sensors):
    self.name = name
    self.model = model
    self.battery = battery
    self.motor = motor
    self.sensors = sensors

  def robot_info(self):
    print(self)
    print("Name : ", self.name, "| Model : ", self.model, "| Battery : ", self.battery.capacity, "kWh| Motor : ", self.motor.power, "Watt")
    print(f"\nIMU {self.sensors['imu'].model}")

  def move(self, direction, distance):
      print(f"{self.name} (model {self.model}) is moving to the {direction} for {distance} meters")

  def get_base_cost(self):
    print(f"The Base Cost of the Robot is = {self.robot_base_cost}")

    # print(f"The Base Cost of the Robot is = {Robot.robot_base_cost}")

# %%
my_first_robot=Robot("R2D2", "Droid", first_robot_battery, motor200, sensors_set1)
my_second_robot=Robot("C3PO", "Droid", first_robot_battery, motor200, sensors_set1)
my_second_robot.robot_info()
# Out:
# <__main__.Robot object at 0x7b3590bde950>
# Name :  C3PO | Model :  Droid | Battery :  4550 kWh| Motor :  200 Watt
#
# IMU MPU6050

# %% [markdown]
# We can access the class variable from the Class itself and the both the instances of the class.

# %%
print(Robot.robot_base_cost)
print(my_first_robot.robot_base_cost)
print(my_second_robot.robot_base_cost)
# Out:
# 100000
# 100000
# 100000

# %% [markdown]
# When we try to access the class variable from instance of a class, it will first check the instance attributes and when it does not find it there, it checks the attributes of the class the instance inherit from and use it.

# %%
my_first_robot.get_base_cost()
Robot.get_base_cost(my_first_robot)
# Out:
# The Base Cost of the Robot is = 100000
# The Base Cost of the Robot is = 100000

# %%
print(my_first_robot.__dict__)
# Out:
# {'name': 'R2D2', 'model': 'Droid', 'battery': <__main__.Battery object at 0x7b3590bdc610>, 'motor': <__main__.Motor object at 0x7b3590bdf790>, 'sensors': {'range_finder': <__main__.RangeFinder object at 0x7b3590bdcd90>, 'imu': <__main__.IMU object at 0x7b3590bdc1f0>, 'camera': <__main__.Camera object at 0x7b3590bdc490>}}

# %%
print(Robot.__dict__)
# Out:
# {'__module__': '__main__', 'robot_base_cost': 100000, '__init__': <function Robot.__init__ at 0x7b357c3e5f30>, 'robot_info': <function Robot.robot_info at 0x7b357c3e7400>, 'move': <function Robot.move at 0x7b357c3e6cb0>, 'get_base_cost': <function Robot.get_base_cost at 0x7b357c3e6170>, '__dict__': <attribute '__dict__' of 'Robot' objects>, '__weakref__': <attribute '__weakref__' of 'Robot' objects>, '__doc__': None}

# %%
Robot.robot_base_cost = 200000
print(Robot.robot_base_cost)
print(my_first_robot.robot_base_cost)
print(my_second_robot.robot_base_cost)
# Out:
# 200000
# 200000
# 200000

# %%
my_first_robot.robot_base_cost = 300000
print(Robot.robot_base_cost)
print(my_first_robot.robot_base_cost)
print(my_second_robot.robot_base_cost)
# Out:
# 200000
# 300000
# 200000

# %%
print(my_first_robot.__dict__)
# Out:
# {'name': 'R2D2', 'model': 'Droid', 'battery': <__main__.Battery object at 0x7b3590bdc610>, 'motor': <__main__.Motor object at 0x7b3590bdf790>, 'sensors': {'range_finder': <__main__.RangeFinder object at 0x7b3590bdcd90>, 'imu': <__main__.IMU object at 0x7b3590bdc1f0>, 'camera': <__main__.Camera object at 0x7b3590bdc490>}, 'robot_base_cost': 300000}

# %% [markdown]
# # Class Method

# %% [markdown]
# We can add another functionality of counting how many objects we have created on Robot Class. As this functionality is not related to any of the object, we use special method named as Class Method for this task.
# <p>The class method is declared by using a decorator <b>@classmethod</b>.</p>
# As this method is not object dependent, so we will not use 'self' but instead, we have to use '<b><i>cls</i></b>'.
#
#  Just to remind that the constructor or the ' _ _ init _ _ ' method is only called by default when the object of the class is instantiated. So, we have to make some changes in the class.
#
# We can also create one method in the Robot Class to count the Robots.
#
# Here the 'total_robots' variable is also based on class, we call this variable as class variable and is initialized at the begining of the class. This is processed (incremented in this case) in the '_ _ init _ _ ' method.

# %%
class Robot():
  total_robots = 0  # Class variable to keep track of the number of Robot instances

  robot_base_cost = 100000

  def __init__(self, name, model, battery, motor, sensors):
    self.name = name
    self.model = model
    self.battery = battery
    self.motor = motor
    self.sensors = sensors
    Robot.total_robots += 1  # Increment the class variable

  def robot_info(self):
    print(self)
    print("Name : ", self.name, "| Model : ", self.model, "| Battery : ", self.battery.capacity, "kWh| Motor : ", self.motor.power, "Watt")
    print("\nThe Robot is equipped with the following Sensors : ")
    print(f"\nIMU {self.sensors['imu'].model}")

  def move(self, direction, distance):
      print(f"{self.name} (model {self.model}) is moving to the {direction} for {distance} meters")

  def get_base_cost(self):
    print(f"The Base Cost of the Robot is = {self.robot_base_cost}")

  # Class method to get the total number of robots
  @classmethod
  def get_total_robots(cls):
    return cls.total_robots

# %%
my_first_robot=Robot("R2D2", "Droid", first_robot_battery, motor200, sensors_set1)
my_second_robot=Robot("C3PO", "Droid", first_robot_battery, motor200, sensors_set1)
my_second_robot.robot_info()
# Out:
# <__main__.Robot object at 0x7b3590bdeef0>
# Name :  C3PO | Model :  Droid | Battery :  4550 kWh| Motor :  200 Watt
#
# The Robot is equipped with the following Sensors :
#
# IMU MPU6050

# %%
# Display the total number of robots and flying robots
print(f"Total robots: {Robot.get_total_robots()}")
print(my_second_robot)
# Out:
# Total robots: 2
# <__main__.Robot object at 0x7b3590bdeef0>

# %% [markdown]
# It is important to note that 'get_base_cost()' is basically is independent of the instance of the class and can be defined as class method. So, we can try to put '@classmethod' decorator and use the method on class rather than instance of the class.

# %% [markdown]
# # Encapsulation

# %% [markdown]
# Encapsulation refers to the bundling of attributes and methods into a class. Encapsulation also restricts direct access to some of an object's components and hides the internal representation of an object from the outside.
# This is achieved using access modifiers.
#
# Now let us try to divide the robot class into two classes to encapsulate the configuration attributes and related methods into one class and the other behavioral methods into another class.
#
# First, let us define our configuration class

# %%
# Define a configuration class to encapsulate all configurations
class RobotConfig:
  def __init__(self, name, model, battery, motor, sensors):
    self.name = name
    self.model = model
    self.battery = battery
    self.motor = motor
    self.sensors = sensors

# %% [markdown]
# Let us also instroduce the concept of private attribute to encapsulate the attribute definitions from outside world. For this we shall make 'name' attribute as private by adding a prefix of '_' (underscore) with the attribute.
#
# This will restrict the direct access of the atrribute and we have to define a method for accessing the attribute. We generally call these 'getter' and 'setter' methods. In this example, we have define a 'get_name()' method as a 'getter'.

# %%
class Robot:

  total_robots = 0  # Class variable to keep track of the number of Robot instances

  robot_base_cost = 100000

  def __init__(self, robo_config):
    self._name = robo_config.name
    self.model = robo_config.model
    self.battery = robo_config.battery  # composition
    self.motor = robo_config.motor  # composition
    self.sensors = robo_config.sensors  # composition
    Robot.total_robots += 1  # Increment the class variable

  def robot_info(self):
    # print(self)
    print(f"Name: {self.get_name} | Model: {self.model} | Battery: {self.battery.capacity} kWh | Motor: {self.motor.power} Watt")
    print(f"IMU {self.sensors['imu'].model}")

  def get_name(self):
    return self._name

  # We need to change
  def move(self, direction, distance):
      print(f"{self.get_name()} (model {self.model}) is moving to the {direction} for {distance} meters")

  def get_base_cost(self):
    print(f"The Base Cost of the Robot is = {self.robot_base_cost}")

    # Class method to get the total number of robots
  @classmethod
  def get_total_robots(cls):
    return cls.total_robots

# %%
print(f"Total robots: {Robot.get_total_robots()}")
# Out:
# Total robots: 0

# %%
# Create configuration objects
robot_config1 = RobotConfig("Robo1", "RX-78", battery1, motor200, sensors_set1)
robot_config2 = RobotConfig("FlyBot1", "FX-99", battery2, motor200, sensors_set2)

# %%
my_first_robot = Robot(robot_config1)
print(my_first_robot.robot_info())
my_second_robot = Robot(robot_config2)
# print(my_second_robot.robot_info())
# Out:
# Name: <bound method Robot.get_name of <__main__.Robot object at 0x7b3590bdf100>> | Model: RX-78 | Battery: 5000 kWh | Motor: 200 Watt
# IMU MPU6050
# None

# %% [markdown]
# # Creating Sub-Classes : Inheritance

# %% [markdown]
# Inheritance allows a class to inherit attributes and methods from another class. The class that inherits is called the "child class" or "subclass," and the class from which it inherits is called the "parent class" or "superclass."
#
# The class that inherits from the parent class can add new properties and methods or override existing ones from the parent class.
#
# Now, to understand this better. Let us create a subclass for 'AerialRobot' which inherits from 'Robot' class. So, 'Robot' class is called as parent class or the Super Class.
#
# For demonstarating the method overriding, let us define a 'move()' method in child class or subclass. We will also propose a different base price of the AerialRobot which was defined as a class variable in both the classes.

# %%
# Define a subclass of Robot to demonstrate inheritance and method overriding
class AerialRobot(Robot):

    total_aerial_robots = 0  # Class variable to keep track of the number AerialRobot instances

    robot_base_cost = 150000

    def __init__(self, config, altitude):
      super().__init__(config)  # call the base class constructor
      # Robot.__init__(self, config) # call the base class constructor
      self.altitude = altitude
      AerialRobot.total_aerial_robots += 1  # Increment the class variable

    # Overriding the move method to include flying behavior
    def move(self, direction, distance):
      print(f"{self.get_name()} (model {self.model}) is flying {direction} for {distance} meters at altitude {self.altitude} meters")

    # Class method to get the total number of flying robots
    @classmethod
    def get_total_aerial_robots(cls):
      return cls.total_aerial_robots

# %%
class Robot:

  total_robots = 0  # Class variable to keep track of the number of Robot instances

  robot_base_cost = 100000

  def __init__(self, robo_config):
    self._name = robo_config.name
    self.model = robo_config.model
    self.battery = robo_config.battery  # composition
    self.motor = robo_config.motor  # composition
    self.sensors = robo_config.sensors  # composition
    Robot.total_robots += 1  # Increment the class variable

  def robot_info(self):
    # print(self)
    print(f"Name: {self.get_name} | Model: {self.model} | Battery: {self.battery.capacity} kWh | Motor: {self.motor.power} Watt")
    print(f"IMU {self.sensors['imu'].model}")

  def get_name(self):
    return self._name

  def move(self, direction, distance):
      print(f"{self.name} (model {self.model}) is moving to the {direction} for {distance} meters")

  def get_base_cost(self):
    print(f"The Base Cost of the Robot is = {self.robot_base_cost}")

  # Class method to get the total number of robots
  @classmethod
  def get_total_robots(cls):
    return cls.total_robots

# %%
my_first_robot = Robot(robot_config1)
# print(my_first_robot.robot_info())
my_second_robot = Robot(robot_config2)
my_first_aerial_robot = AerialRobot(robot_config1, 100)
my_second_aerial_robot = AerialRobot(robot_config2, 200)

# %%
my_first_robot.move("forward", 5)
my_first_aerial_robot.move("forward", 5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-185-e6454a69ddfc> in <cell line: 1>()
# ----> 1 my_first_robot.move("forward", 5)
#       2 my_first_aerial_robot.move("forward", 5)
#
# <ipython-input-183-36098757d180> in move(self, direction, distance)
#      22
#      23   def move(self, direction, distance):
# ---> 24       print(f"{self.name} (model {self.model}) is moving to the {direction} for {distance} meters")
#      25
#      26   def get_base_cost(self):
#
# AttributeError: 'Robot' object has no attribute 'name'

# %%
my_first_robot.get_base_cost()
my_first_aerial_robot.get_base_cost()
# Out:
# The Base Cost of the Robot is = 100000
# The Base Cost of the Robot is = 150000

# %% [markdown]
# # Polymorphism

# %% [markdown]
# Polymorphism, an essential concept in OOP, allows the same interface to be used for different underlying forms (data types or objects). It can be categorized into two types: method overriding (runtime polymorphism) and operator overloading (compile-time polymorphism).
#
# 1. Method Overriding (Runtime Polymorphism):
#
# Definition:
# Method overriding occurs when a subclass provides a specific implementation of a method that is already defined in its superclass. The subclass method overrides the superclass method, and the method call is resolved at runtime based on the object's actual type.
#
# In the Robot Example:
#
# The move method in the Robot class is overridden in the FlyingRobot class.
# Depending on whether the object is of type Robot or FlyingRobot, the corresponding move method is executed.
#
# The 'operate_robot' function demonstrates polymorphism by accepting any object that has a move method. It can operate both Robot and FlyingRobot instances, showing how different objects can be treated uniformly.

# %%
# Define a function to demonstrate polymorphism
def operate_robot(robot, direction, distance):
    robot.move(direction, distance)

# %%
# print(help(AerialRobot))

# %%
# operate_robot(my_first_robot, "left", 5)
operate_robot(my_first_aerial_robot, "right", 15)
# Out:
# Robo1 (model RX-78) is flying right for 15 meters at altitude 100 meters

# %%
print(isinstance(my_first_robot, Robot))
print(isinstance(my_first_robot, AerialRobot))
print(isinstance(my_first_aerial_robot, Robot))
print(isinstance(my_first_aerial_robot, AerialRobot))
print(issubclass(AerialRobot, Robot))  # Check if AerialRobot is a subclass of Robot
print(issubclass(Robot, AerialRobot))  # Check if Robot is a subclass of Aerial
# Out:
# True
# False
# False
# True
# False
# False

# %% [markdown]
# Operator Overloading (Compile-Time Polymorphism):
#
# Definition:
# Operator overloading allows the same operator to have different meanings based on the context. In Python, this is achieved by defining special methods like __add__, __sub__, __mul__, etc.
#
# Extending the Robot Example:
# Suppose we want to combine the battery capacities of two robots when using the + operator on their objects. We can overload the + operator in the Robot class.

# %%
class Robot:
    # Existing methods remain unchanged

    def __add__(self, other):
        if isinstance(other, Robot):
            return self.battery.capacity + other.battery.capacity
        raise TypeError("Addition only supported between Robot instances")

# Example Usage:
robot1 = Robot(config1)
robot2 = Robot(config2)

combined_capacity = robot1 + robot2
print(f"Combined battery capacity: {combined_capacity}mAh")
# Output: Combined battery capacity: 13000mAh
